# %%
import pandas as pd

# %%
usar = pd.read_csv('../csv/usar.csv', ",")

# %%
usar['Name'] = usar['Name'].str.lower()

# %%
usar
# Out:
#                   Name  Rank Change  Rating  Wins  Losses  Tournaments  \
# 0        gabe finocchi     1     --  156.90   111      28          9.0
# 1      thomas hamilton     2     --  156.26    95      22          8.0
# 2          ryan marino     3      1  155.58   113      29         10.0
# 3    ryder rivadeneyra     4      1  155.54    23       5          2.0
# 4         rahul murthy     5      3  151.82   114      37         11.0
# ..                 ...   ...    ...     ...   ...     ...          ...
# 479          noah yost   485      7   64.93     3      11          2.0
# 480          yibin han   486      3   58.81     1      11          2.0
# 481       daniil tuder   486      3   58.81     1      11          2.0
# 482         luke nemec   488      8   58.74     1      17          2.0
# 483            aj yoon   489     11   46.71     0      13          2.0
#
#      Avg Partner Rating  Avg Opp Rating
# 0                144.61          138.91
# ...
